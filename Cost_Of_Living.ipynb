# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# About Dataset
#
# This dataset contains information about the cost of living in almost 5000 cities across the world. The data were gathered by scraping Numbeo's website (https://www.numbeo.com).
# Data dictionary:
# Column 	Description
# 1. city 	Name of the city
# 2. country 	Name of the country
# 3. x1 	Meal, Inexpensive Restaurant (USD)
# 4. x2 	Meal for 2 People, Mid-range Restaurant, Three-course (USD)
# 5. x3 	McMeal at McDonalds (or Equivalent Combo Meal) (USD)
# 6. x4 	Domestic Beer (0.5 liter draught, in restaurants) (USD)
# 7. x5 	Imported Beer (0.33 liter bottle, in restaurants) (USD)
# 8. x6 	Cappuccino (regular, in restaurants) (USD)
# 9. x7 	Coke/Pepsi (0.33 liter bottle, in restaurants) (USD)
# 10. x8 	Water (0.33 liter bottle, in restaurants) (USD)
# 11. x9 	Milk (regular), (1 liter) (USD)
# 12. x10 	Loaf of Fresh White Bread (500g) (USD)
# 13. x11 	Rice (white), (1kg) (USD)
# 14. x12 	Eggs (regular) (12) (USD)
# 15. x13 	Local Cheese (1kg) (USD)
# 16. x14 	Chicken Fillets (1kg) (USD)
# 17. x15 	Beef Round (1kg) (or Equivalent Back Leg Red Meat) (USD)
# 18. x16 	Apples (1kg) (USD)
# 19. x17 	Banana (1kg) (USD)
# 20. x18 	Oranges (1kg) (USD)
# 21. x19 	Tomato (1kg) (USD)
# 22. x20 	Potato (1kg) (USD)
# 23. x21 	Onion (1kg) (USD)
# 24. x22 	Lettuce (1 head) (USD)
# 25. x23 	Water (1.5 liter bottle, at the market) (USD)
# 26. x24 	Bottle of Wine (Mid-Range, at the market) (USD)
# 27. x25 	Domestic Beer (0.5 liter bottle, at the market) (USD)
# 28. x26 	Imported Beer (0.33 liter bottle, at the market) (USD)
# 29. x27 	Cigarettes 20 Pack (Marlboro) (USD)
# 30. x28 	One-way Ticket (Local Transport) (USD)
# 31. x29 	Monthly Pass (Regular Price) (USD)
# 32. x30 	Taxi Start (Normal Tariff) (USD)
# 33. x31 	Taxi 1km (Normal Tariff) (USD)
# 34. x32 	Taxi 1hour Waiting (Normal Tariff) (USD)
# 35. x33 	Gasoline (1 liter) (USD)
# 36. x34 	Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car) (USD)
# 37. x35 	Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car) (USD)
# 38. x36 	Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment (USD)
# 39. x37 	1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans) (USD)
# 40. x38 	Internet (60 Mbps or More, Unlimited Data, Cable/ADSL) (USD)
# 41. x39 	Fitness Club, Monthly Fee for 1 Adult (USD)
# 42. x40 	Tennis Court Rent (1 Hour on Weekend) (USD)
# 43. x41 	Cinema, International Release, 1 Seat (USD)
# 44. x42 	Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)
# 45. x43 	International Primary School, Yearly for 1 Child (USD)
# 46. x44 	1 Pair of Jeans (Levis 501 Or Similar) (USD)
# 47. x45 	1 Summer Dress in a Chain Store (Zara, H&M, …) (USD)
# 48. x46 	1 Pair of Nike Running Shoes (Mid-Range) (USD)
# 49. x47 	1 Pair of Men Leather Business Shoes (USD)
# 50. x48 	Apartment (1 bedroom) in City Centre (USD)
# 51. x49 	Apartment (1 bedroom) Outside of Centre (USD)
# 52. x50 	Apartment (3 bedrooms) in City Centre (USD)
# 53. x51 	Apartment (3 bedrooms) Outside of Centre (USD)
# 54. x52 	Price per Square Meter to Buy Apartment in City Centre (USD)
# 55. x53 	Price per Square Meter to Buy Apartment Outside of Centre (USD)
# 56. x54 	Average Monthly Net Salary (After Tax) (USD)
# 57. x55 	Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 58. data_quality 	0 if Numbeo considers that more contributors are needed to increase data quality, else 1

# %%
df=pd.read_csv('cost-of-living.csv',index_col=0)
df
# Out:
#                     city      country     x1     x2     x3     x4    x5    x6  \
# 0                  Delhi        India   4.90  22.04   4.28   1.84  3.67  1.78
# 1               Shanghai        China   5.59  40.51   5.59   1.12  4.19  3.96
# 2                Jakarta    Indonesia   2.54  22.25   3.50   2.02  3.18  2.19
# 3                 Manila  Philippines   3.54  27.40   3.54   1.24  1.90  2.91
# 4                  Seoul  South Korea   7.16  52.77   6.03   3.02  4.52  3.86
# ...                  ...          ...    ...    ...    ...    ...   ...   ...
# 4869        Peterborough    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4870          Georgetown    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4871  Ixtapa Zihuatanejo       Mexico   5.19  31.13  12.97   0.99   NaN  1.82
# 4872             Iqaluit       Canada  29.78  74.61  13.77   6.70  8.93  3.72
# 4873              Neiafu        Tonga    NaN  29.53  10.55  10.55   NaN   NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4874 entries, 0 to 4873
# Data columns (total 58 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          4874 non-null   object
#  1   country       4874 non-null   object
#  2   x1            4449 non-null   float64
#  3   x2            4432 non-null   float64
#  4   x3            4552 non-null   float64
#  5   x4            4385 non-null   float64
#  6   x5            4445 non-null   float64
#  7   x6            4540 non-null   float64
#  8   x7            4438 non-null   float64
#  9   x8            4571 non-null   float64
#  10  x9            4494 non-null   float64
#  11  x10           4457 non-null   float64
#  12  x11           4538 non-null   float64
#  13  x12           4369 non-null   float64
#  14  x13           4393 non-null   float64
#  15  x14           4318 non-null   float64
#  16  x15           4312 non-null   float64
# ...

# %% [markdown]
# From the above snippet of the dataframe it appears some rows have no values in all columns

# %%
#drop rows that have missing values in all columns
df=df.dropna(how='all')
df
# Out:
#                     city      country     x1     x2     x3     x4    x5    x6  \
# 0                  Delhi        India   4.90  22.04   4.28   1.84  3.67  1.78
# 1               Shanghai        China   5.59  40.51   5.59   1.12  4.19  3.96
# 2                Jakarta    Indonesia   2.54  22.25   3.50   2.02  3.18  2.19
# 3                 Manila  Philippines   3.54  27.40   3.54   1.24  1.90  2.91
# 4                  Seoul  South Korea   7.16  52.77   6.03   3.02  4.52  3.86
# ...                  ...          ...    ...    ...    ...    ...   ...   ...
# 4869        Peterborough    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4870          Georgetown    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4871  Ixtapa Zihuatanejo       Mexico   5.19  31.13  12.97   0.99   NaN  1.82
# 4872             Iqaluit       Canada  29.78  74.61  13.77   6.70  8.93  3.72
# 4873              Neiafu        Tonga    NaN  29.53  10.55  10.55   NaN   NaN
#
# ...

# %% [markdown]
# Mmhhh looks like I was wrong...they just appeared to be that way

# %% [markdown]
# SOUTH AFRICA DATASET

# %%
#create a subset of the DataFrame which has South African Data
df_mzansi=df[df['country']=='South Africa']
df_mzansi
# Out:
#                   city       country     x1     x2    x3    x4    x5    x6  \
# 124       Johannesburg  South Africa   8.78  38.06  4.36  2.34  2.34  1.87
# 344             Soweto  South Africa   7.32  29.28  4.10  1.17  2.34  1.76
# 409        Vereeniging  South Africa  11.12  39.52  4.68  1.17  1.46  2.05
# 459           Pretoria  South Africa   7.32  35.13  4.68  1.76  2.05  1.68
# 484          Cape Town  South Africa   8.78  35.13  4.10  2.34  2.63  1.84
# 495       Bloemfontein  South Africa   4.98  32.20  3.66  1.76  1.76  2.07
# 644   Pietermaritzburg  South Africa   7.03  32.20  3.81  1.76  1.87  1.77
# 765             Durban  South Africa   8.78  35.13  4.10  1.87  2.34  1.76
# 981             Welkom  South Africa   3.28  35.13  4.24  1.99  2.34  1.05
# 1138       East London  South Africa   5.86  27.81  3.66  2.05  2.34  1.81
# 1145          Randburg  South Africa   7.03  17.57  4.10  1.76  2.05  1.68
# ...

# %%
#drop the 'country' column in df_mzansi since all the cities are South African
df_mzansi=df_mzansi.drop('country',axis=1)
df_mzansi
# Out:
#                   city     x1     x2    x3    x4    x5    x6    x7    x8  \
# 124       Johannesburg   8.78  38.06  4.36  2.34  2.34  1.87  0.92  0.74
# 344             Soweto   7.32  29.28  4.10  1.17  2.34  1.76  1.07  0.69
# 409        Vereeniging  11.12  39.52  4.68  1.17  1.46  2.05  0.97  0.79
# 459           Pretoria   7.32  35.13  4.68  1.76  2.05  1.68  0.90  0.71
# 484          Cape Town   8.78  35.13  4.10  2.34  2.63  1.84  0.91  0.69
# 495       Bloemfontein   4.98  32.20  3.66  1.76  1.76  2.07  1.11  0.81
# 644   Pietermaritzburg   7.03  32.20  3.81  1.76  1.87  1.77  0.80  0.60
# 765             Durban   8.78  35.13  4.10  1.87  2.34  1.76  0.96  0.73
# 981             Welkom   3.28  35.13  4.24  1.99  2.34  1.05  0.89  0.64
# 1138       East London   5.86  27.81  3.66  2.05  2.34  1.81  0.95  0.70
# 1145          Randburg   7.03  17.57  4.10  1.76  2.05  1.68  0.90  0.69
# 1180        Roodepoort   8.20  35.13  4.10  1.76  2.34  1.66  0.89  0.86
# ...

# %%
#set the city column as the index of the dataset
df_mzansi=df_mzansi.set_index('city')
df_mzansi.head(3)
# Out:
#                  x1     x2    x3    x4    x5    x6    x7    x8    x9   x10  \
# city
# Johannesburg   8.78  38.06  4.36  2.34  2.34  1.87  0.92  0.74  1.09  0.90
# Soweto         7.32  29.28  4.10  1.17  2.34  1.76  1.07  0.69  0.91  0.76
# Vereeniging   11.12  39.52  4.68  1.17  1.46  2.05  0.97  0.79  1.17  0.82
#
#               ...    x47     x48     x49     x50     x51     x52     x53  \
# city          ...
# Johannesburg  ...  74.88  415.04  377.73  790.55  734.38  775.06  688.59
# Soweto        ...  70.26  304.46  363.01  468.41  497.68     NaN     NaN
# Vereeniging   ...  76.06     NaN     NaN     NaN     NaN     NaN     NaN
#
#                   x54   x55  data_quality
# city
# Johannesburg  1549.63  8.88             1
# Soweto            NaN  9.92             0
# Vereeniging   1171.02  9.75             0
#
# [3 rows x 56 columns]

# %% [markdown]
# At the time (2023/01/21) of this analysis, one 1 United States Dollar is ~ 17 South African Rand

# %%
#convert all the values in df_mzansi from USD to ZAR
df_mzansi.loc[:,'x1':'x54']=df_mzansi.loc[:,'x1':'x54'].apply(lambda p:p*17)
df_mzansi
# Out:
#                       x1      x2     x3     x4     x5     x6     x7     x8  \
# city
# Johannesburg      149.26  647.02  74.12  39.78  39.78  31.79  15.64  12.58
# Soweto            124.44  497.76  69.70  19.89  39.78  29.92  18.19  11.73
# Vereeniging       189.04  671.84  79.56  19.89  24.82  34.85  16.49  13.43
# Pretoria          124.44  597.21  79.56  29.92  34.85  28.56  15.30  12.07
# Cape Town         149.26  597.21  69.70  39.78  44.71  31.28  15.47  11.73
# Bloemfontein       84.66  547.40  62.22  29.92  29.92  35.19  18.87  13.77
# Pietermaritzburg  119.51  547.40  64.77  29.92  31.79  30.09  13.60  10.20
# Durban            149.26  597.21  69.70  31.79  39.78  29.92  16.32  12.41
# Welkom             55.76  597.21  72.08  33.83  39.78  17.85  15.13  10.88
# East London        99.62  472.77  62.22  34.85  39.78  30.77  16.15  11.90
# Randburg          119.51  298.69  69.70  29.92  34.85  28.56  15.30  11.73
# ...

# %%
#check the number of missing values in each column
df_mzansi_null=df_mzansi.isnull().sum().reset_index().rename(columns={'index':'column',0:'Missing_Values'})
#get the percentage(%) of missing values in each column
df_mzansi_null['Missing_%']=df_mzansi_null['Missing_Values'].apply(lambda n:round((n/df_mzansi.shape[0])*100),2)
df_mzansi_null
# Out:
#           column  Missing_Values  Missing_%
# 0             x1               1          3
# 1             x2               1          3
# 2             x3               1          3
# 3             x4               2          6
# 4             x5               2          6
# 5             x6               2          6
# 6             x7               1          3
# 7             x8               3          9
# 8             x9               0          0
# 9            x10               0          0
# 10           x11               2          6
# 11           x12               0          0
# 12           x13               0          0
# 13           x14               0          0
# 14           x15               0          0
# 15           x16               1          3
# 16           x17               1          3
# 17           x18               1          3
# 18           x19               1          3
# 19           x20               1          3
# ...

# %% [markdown]
# Some columns appear to have significantly more missing values, but by looking at the dataset it appears to be more row specific in that some rows just have more missing values in most columns

# %%
for i in df_mzansi.index:
    print(f" {i} has missing {df_mzansi.loc[i].isnull().sum()} values")
    print(f" And that's {round((((df_mzansi.loc[i].isnull().sum())/(len(df_mzansi.columns)))*100),2)}% of the values missing in the row",end='\n\n')
# Out:
#  Johannesburg has missing 0 values
#  And that's 0.0% of the values missing in the row
#
#  Soweto has missing 8 values
#  And that's 14.29% of the values missing in the row
#
#  Vereeniging has missing 10 values
#  And that's 17.86% of the values missing in the row
#
#  Pretoria has missing 0 values
#  And that's 0.0% of the values missing in the row
#
#  Cape Town has missing 0 values
#  And that's 0.0% of the values missing in the row
#
#  Bloemfontein has missing 1 values
#  And that's 1.79% of the values missing in the row
#
#  Pietermaritzburg has missing 5 values
#  And that's 8.93% of the values missing in the row
#
#  Durban has missing 0 values
#  And that's 0.0% of the values missing in the row
#
#  Welkom has missing 10 values
#  And that's 17.86% of the values missing in the row
#
#  East London has missing 4 values
#  And that's 7.14% of the values missing in the row
#
#  Randburg has missing 0 values
#  And that's 0.0% of the values missing in the row
#
# ...

# %% [markdown]
# Looks like some cities have a significant amount of missing values so, I'm going to drop cities(rows) that have 10 or more values missing.

# %%
before_drop=len(df_mzansi.index)
before_drop
# Out:
# 34

# %%
for i in df_mzansi.index:
    if (df_mzansi.loc[i].isnull().sum())>=10:
        df_mzansi.drop(i,inplace=True)

# %%
after_drop=len(df_mzansi.index)
after_drop
# Out:
# 27

# %%
cities_dropped=before_drop-after_drop
print(f'{cities_dropped} cities didn\'t make the cut')
# Out:
# 7 cities didn't make the cut

# %%
df_mzansi
# Out:
#                       x1      x2     x3     x4     x5     x6     x7     x8  \
# city
# Johannesburg      149.26  647.02  74.12  39.78  39.78  31.79  15.64  12.58
# Soweto            124.44  497.76  69.70  19.89  39.78  29.92  18.19  11.73
# Pretoria          124.44  597.21  79.56  29.92  34.85  28.56  15.30  12.07
# Cape Town         149.26  597.21  69.70  39.78  44.71  31.28  15.47  11.73
# Bloemfontein       84.66  547.40  62.22  29.92  29.92  35.19  18.87  13.77
# Pietermaritzburg  119.51  547.40  64.77  29.92  31.79  30.09  13.60  10.20
# Durban            149.26  597.21  69.70  31.79  39.78  29.92  16.32  12.41
# East London        99.62  472.77  62.22  34.85  39.78  30.77  16.15  11.90
# Randburg          119.51  298.69  69.70  29.92  34.85  28.56  15.30  11.73
# Roodepoort        139.40  597.21  69.70  29.92  39.78  28.22  15.13  14.62
# Port Elizabeth    218.96  746.47  84.66  34.85  44.71  30.77  18.02  13.26
# ...

# %% [markdown]
# The column 'data_quality' indicates whether or not more comtributors are needed to increase data quality 0 if Numbeo considers that more contributors are needed to increase data quality, else 1, most of the south african cities are 0 so I'm just going to drop the column. also drop the x55 column

# %%
df_mzansi=df_mzansi.drop(['data_quality','x55'],axis=1)
df_mzansi.head(3)
# Out:
#                   x1      x2     x3     x4     x5     x6     x7     x8     x9  \
# city
# Johannesburg  149.26  647.02  74.12  39.78  39.78  31.79  15.64  12.58  18.53
# Soweto        124.44  497.76  69.70  19.89  39.78  29.92  18.19  11.73  15.47
# Pretoria      124.44  597.21  79.56  29.92  34.85  28.56  15.30  12.07  17.17
#
#                 x10  ...     x45      x46      x47      x48      x49  \
# city                 ...
# Johannesburg  15.30  ...  461.04  1477.98  1272.96  7055.68  6421.41
# Soweto        12.92  ...  325.21   796.28  1194.42  5175.82  6171.17
# Pretoria      14.45  ...  546.72  1368.50  1498.89  5305.36  5847.83
#
#                    x50       x51       x52       x53       x54
# city
# Johannesburg  13439.35  12484.46  13176.02  11706.03  26343.71
# Soweto         7962.97   8460.56       NaN       NaN       NaN
# Pretoria      12475.28  12261.08   7664.28  10780.04  23617.59
#
# [3 rows x 54 columns]

# %% [markdown]
# Create a column that sums up the values in each city to get the cumulative cost of living in each city.

# %%
#sum all the values in the columns per row i.e per city to find the total
df_mzansi['Total']=df_mzansi.sum(axis=1)
df_mzansi.head(3)
# Out:
#                   x1      x2     x3     x4     x5     x6     x7     x8     x9  \
# city
# Johannesburg  149.26  647.02  74.12  39.78  39.78  31.79  15.64  12.58  18.53
# Soweto        124.44  497.76  69.70  19.89  39.78  29.92  18.19  11.73  15.47
# Pretoria      124.44  597.21  79.56  29.92  34.85  28.56  15.30  12.07  17.17
#
#                 x10  ...      x46      x47      x48      x49       x50  \
# city                 ...
# Johannesburg  15.30  ...  1477.98  1272.96  7055.68  6421.41  13439.35
# Soweto        12.92  ...   796.28  1194.42  5175.82  6171.17   7962.97
# Pretoria      14.45  ...  1368.50  1498.89  5305.36  5847.83  12475.28
#
#                    x51       x52       x53       x54      Total
# city
# Johannesburg  12484.46  13176.02  11706.03  26343.71  892095.57
# Soweto         8460.56       NaN       NaN       NaN  466954.64
# Pretoria      12261.08   7664.28  10780.04  23617.59  806495.47
#
# [3 rows x 55 columns]

# %% [markdown]
# SOUTH AFRICAN CITIES AGRICULTURAL GOOD DATASET

# %% [markdown]
# My training is in agricultural economics so I would like to select only a subset of the df_mzansi dataset that includes agricultural/food products.

# %%
df_agric_mzansi=df_mzansi.loc[:,'x1':'x27']
df_agric_mzansi
# Out:
#                       x1      x2     x3     x4     x5     x6     x7     x8  \
# city
# Johannesburg      149.26  647.02  74.12  39.78  39.78  31.79  15.64  12.58
# Soweto            124.44  497.76  69.70  19.89  39.78  29.92  18.19  11.73
# Pretoria          124.44  597.21  79.56  29.92  34.85  28.56  15.30  12.07
# Cape Town         149.26  597.21  69.70  39.78  44.71  31.28  15.47  11.73
# Bloemfontein       84.66  547.40  62.22  29.92  29.92  35.19  18.87  13.77
# Pietermaritzburg  119.51  547.40  64.77  29.92  31.79  30.09  13.60  10.20
# Durban            149.26  597.21  69.70  31.79  39.78  29.92  16.32  12.41
# East London        99.62  472.77  62.22  34.85  39.78  30.77  16.15  11.90
# Randburg          119.51  298.69  69.70  29.92  34.85  28.56  15.30  11.73
# Roodepoort        139.40  597.21  69.70  29.92  39.78  28.22  15.13  14.62
# Port Elizabeth    218.96  746.47  84.66  34.85  44.71  30.77  18.02  13.26
# ...

# %%
#create a 'Groceries' column which is the summation of all the products in df_agric_mzansi dataframe for all the cities.
df_agric_mzansi['Groceries']=df_agric_mzansi.sum(axis=1)
df_agric_mzansi.head(3)
# Out:
#                   x1      x2     x3     x4     x5     x6     x7     x8     x9  \
# city
# Johannesburg  149.26  647.02  74.12  39.78  39.78  31.79  15.64  12.58  18.53
# Soweto        124.44  497.76  69.70  19.89  39.78  29.92  18.19  11.73  15.47
# Pretoria      124.44  597.21  79.56  29.92  34.85  28.56  15.30  12.07  17.17
#
#                 x10  ...    x19    x20    x21    x22    x23    x24    x25  \
# city                 ...
# Johannesburg  15.30  ...  25.84  23.80  20.74  17.34  16.66  79.56  24.65
# Soweto        12.92  ...  19.38  17.85  18.87  13.43  14.96  67.15  17.00
# Pretoria      14.45  ...  23.63  20.23  19.04  16.32  16.32  79.56  22.44
#
#                 x26    x27  Groceries
# city
# Johannesburg  29.92  49.81    1787.55
# Soweto        20.57  42.33    1336.88
# Pretoria      31.62  49.81    1654.78
#
# [3 rows x 28 columns]

# %%
df_agric_mzansi[['Groceries']].describe()
# Out:
#         Groceries
# count    27.00000
# mean   1542.07000
# std     209.48812
# min    1219.07000
# 25%    1330.42000
# 50%    1572.67000
# 75%    1701.87000
# max    1973.19000

# %%
print(f"The average cost of groceries in South African cities is R{round(df_agric_mzansi['Groceries'].mean(),0)}")
# Out:
# The average cost of groceries in South African cities is R1542.0

# %%
most_expensive_groceries=df_agric_mzansi.index[df_agric_mzansi['Groceries']==df_agric_mzansi['Groceries'].max()][0]
cheapest_groceries=df_agric_mzansi.index[df_agric_mzansi['Groceries']==df_agric_mzansi['Groceries'].min()][0]

# %%
print(f"The city with the most expensive basket of groceries is {most_expensive_groceries}, at R{round(df_agric_mzansi['Groceries'].max(),0)}", end='\n\n')
print(f"The city with the cheapest basket of groceries is {cheapest_groceries},at R{round(df_agric_mzansi['Groceries'].min(),0)}")
# Out:
# The city with the most expensive basket of groceries is Port Elizabeth, at R1973.0
#
# The city with the cheapest basket of groceries is Jeffrey's Bay,at R1219.0

# %% [markdown]
# Let's see where groceries cost more between Johannesburg and Cape Town

# %%
groceries_cpt=df_agric_mzansi.loc['Cape Town','Groceries']
groceries_jhb=df_agric_mzansi.loc['Johannesburg','Groceries']

# %%
if groceries_cpt>groceries_jhb:
    print(f"Groceries cost R{round(groceries_cpt-groceries_jhb,0)} more at Cape Town than Johannesburg")
elif groceries_jhb>groceries_cpt:
    print(f"Groceries cost R{round(groceries_jhb-groceries_cpt,0)} more at Johannesburg than Cape Town")
else:
    print('Groceries cost the same in Johannesburg and Cape Town')
# Out:
# Groceries cost R75.0 more at Johannesburg than Cape Town

# %% [markdown]
# BACK TO THE FULL DATASET

# %% [markdown]
# SALARIES:

# %%
df_mzansi.rename(columns={'x54':'Average_Salary'},inplace=True)
df_mzansi['Average_Salary']
# Out:
# city
# Johannesburg        26343.71
# Soweto                   NaN
# Pretoria            23617.59
# Cape Town           21902.97
# Bloemfontein        22229.71
# Pietermaritzburg    20570.85
# Durban              18843.82
# East London         19309.96
# Randburg            28533.65
# Roodepoort          15428.18
# Port Elizabeth      20075.98
# Centurion           27538.30
# Sandton             34107.78
# Polokwane           33842.41
# Klerksdorp          18911.82
# Rustenburg          29860.84
# Benoni              26377.03
# George              14930.42
# Potchefstroom       11446.61
# Alberton            20239.01
# Uitenhage           20902.69
# Nelspruit           21400.28
# Mossel Bay          11944.37
# Knysna               6768.55
# Jeffrey's Bay       13935.07
# Hermanus             6967.62
# Villiersdorp        31842.70
# Name: Average_Salary, dtype: float64

# %%
df_mzansi[['Average_Salary']].describe()
# Out:
#        Average_Salary
# count       26.000000
# mean     21071.996923
# std       7491.333384
# min       6768.550000
# 25%      16282.090000
# 50%      20736.770000
# 75%      26368.700000
# max      34107.780000

# %%
df_mzansi['Average_Salary'].fillna(df_mzansi['Average_Salary'].mean(),inplace=True)
df_mzansi['Average_Salary']
# Out:
# city
# Johannesburg        26343.710000
# Soweto              21071.996923
# Pretoria            23617.590000
# Cape Town           21902.970000
# Bloemfontein        22229.710000
# Pietermaritzburg    20570.850000
# Durban              18843.820000
# East London         19309.960000
# Randburg            28533.650000
# Roodepoort          15428.180000
# Port Elizabeth      20075.980000
# Centurion           27538.300000
# Sandton             34107.780000
# Polokwane           33842.410000
# Klerksdorp          18911.820000
# Rustenburg          29860.840000
# Benoni              26377.030000
# George              14930.420000
# Potchefstroom       11446.610000
# Alberton            20239.010000
# Uitenhage           20902.690000
# Nelspruit           21400.280000
# Mossel Bay          11944.370000
# Knysna               6768.550000
# Jeffrey's Bay       13935.070000
# Hermanus             6967.620000
# Villiersdorp        31842.700000
# Name: Average_Salary, dtype: float64

# %%
print(f"The average salary of South African cities is R{round(df_mzansi['Average_Salary'].mean(),0)}")
# Out:
# The average salary of South African cities is R21072.0

# %%
Highest_Salary=df_mzansi['Average_Salary'].max()
Highest_Paying_City=df_mzansi.index[df_mzansi['Average_Salary']==df_mzansi['Average_Salary'].max()][0]

# %%
print(f"The city with the highest average salary is {Highest_Paying_City} at R{Highest_Salary}")
# Out:
# The city with the highest average salary is Sandton at R34107.78

# %%
Lowest_Salary=df_mzansi['Average_Salary'].min()
Lowest_Paying_City=df_mzansi.index[df_mzansi['Average_Salary']==df_mzansi['Average_Salary'].min()][0]

# %%
print(f"The city with the lowest average salary is {Lowest_Paying_City} at R{round(Lowest_Salary,2)}")
# Out:
# The city with the lowest average salary is Knysna at R6768.55

# %% [markdown]
# HOUSING:

# %% [markdown]
# 1. x48 Apartment (1 bedroom) in City Centre (ZAR)
# 2. x49 Apartment (1 bedroom) Outside of Centre (ZAR)
# 3. x50 Apartment (3 bedrooms) in City Centre (ZAR)
# 4. x51 Apartment (3 bedrooms) Outside of Centre (ZAR)
# 5. x52 Price per Square Meter to Buy Apartment in City Centre (ZAR)
# 6. x53 Price per Square Meter to Buy Apartment Outside of Centre (ZAR)

# %%
df_mzansi_housing=df_mzansi.loc[:,'x48':'x53']
df_mzansi_housing.head()
# Out:
#                    x48      x49       x50       x51       x52       x53
# city
# Johannesburg   7055.68  6421.41  13439.35  12484.46  13176.02  11706.03
# Soweto         5175.82  6171.17   7962.97   8460.56       NaN       NaN
# Pretoria       5305.36  5847.83  12475.28  12261.08   7664.28  10780.04
# Cape Town     12285.56  8198.93  24064.52  16213.41  35844.33  24881.03
# Bloemfontein   2936.24  3981.40   8128.72   9157.39  44791.26  41058.74

# %%
df_mzansi_housing.describe()
# Out:
#                 x48           x49           x50           x51           x52  \
# count     26.000000     25.000000     27.000000     26.000000     19.000000
# mean    6050.280385   5841.206800  11711.539259  12421.448846  15868.086316
# std     2564.142859   2179.208603   4532.431626   4713.964928   9450.755979
# min     1791.630000   1990.700000   5723.390000   4479.160000   5972.100000
# 25%     4976.750000   4230.280000   8294.640000   9704.747500  10734.395000
# 50%     5640.430000   5640.430000  10700.140000  11944.370000  14134.140000
# 75%     7033.665000   7465.210000  14018.965000  12473.835000  16821.670000
# max    12285.560000  10451.260000  24064.520000  25879.440000  44791.260000
#
#                 x53
# count     20.000000
# mean   13180.746000
# std     7810.220402
# min     5623.770000
# 25%     8199.822500
# 50%    11848.320000
# 75%    13974.382500
# max    41058.740000

# %%
#fill the null values in the df_mzansi_housing dataframe with the median value of each column.
for col in df_mzansi_housing.columns:
    df_mzansi_housing[col].fillna(df_mzansi_housing[col].median(),inplace=True)
df_mzansi_housing.head()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#                    x48      x49       x50       x51       x52       x53
# city
# Johannesburg   7055.68  6421.41  13439.35  12484.46  13176.02  11706.03
# Soweto         5175.82  6171.17   7962.97   8460.56  14134.14  11848.32
# Pretoria       5305.36  5847.83  12475.28  12261.08   7664.28  10780.04
# Cape Town     12285.56  8198.93  24064.52  16213.41  35844.33  24881.03
# Bloemfontein   2936.24  3981.40   8128.72   9157.39  44791.26  41058.74

# %%
cheapest_city_centre_apt1BD=df_mzansi_housing.index[df_mzansi_housing['x48']==df_mzansi_housing['x48'].min()][0]
print(f"The city with the cheapest city centre 1 Bedroom apartment is {cheapest_city_centre_apt1BD} and it costs R{df_mzansi_housing['x48'].min()}")
# Out:
# The city with the cheapest city centre 1 Bedroom apartment is Klerksdorp and it costs R1791.63

# %%
expensive_city_centre_apt1BD=df_mzansi_housing.index[df_mzansi_housing['x48']==df_mzansi_housing['x48'].max()][0]
print(f"The city with the most expenisve city centre 1 Bedroom apartment is {expensive_city_centre_apt1BD} and it costs R{df_mzansi_housing['x48'].max()}")
# Out:
# The city with the most expenisve city centre 1 Bedroom apartment is Cape Town and it costs R12285.56

# %% [markdown]
# No suprises there..

# %%
print(f"The average cost of a city centre 1 Bedroom apartment is R{round(df_mzansi_housing['x48'].mean(),2)}")
# Out:
# The average cost of a city centre 1 Bedroom apartment is R6035.1

# %%
print(f"The average cost of a 1 Bedroom apartment outside city centre is R{round(df_mzansi_housing['x49'].mean(),2)}")
# Out:
# The average cost of a 1 Bedroom apartment outside city centre is R5826.33

# %%
print(f"It costs on average R{round((round(df_mzansi_housing['x48'].mean(),2))-(round(df_mzansi_housing['x49'].mean(),2)),2)} more to rent a 1BD apartment in the city centre than outside")
# Out:
# It costs on average R208.77 more to rent a 1BD apartment in the city centre than outside
